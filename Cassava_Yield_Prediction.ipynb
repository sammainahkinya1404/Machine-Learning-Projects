# %% [markdown]
# <a href="https://colab.research.google.com/github/sammainahkinya1404/Machine-Learning/blob/main/Cassava_Yield_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read all the Three Datasets
df1=pd.read_csv('/content/Temperature.csv')
df2=pd.read_csv('/content/cassava-yields.csv')
df3=pd.read_csv('/content/rainfall.csv')


df1.head(5)
# Out:
#    Year average_rain_fall_mm_per_year
# 0  1985                           327
# 1  1986                           327
# 2  1987                           327
# 3  1989                           327
# 4  1990                           327

# %%
df2.head(5)
# Out:
#    Year  Crops - Cassava - 125 - Yield - 5419 - hg/ha
# 0  1961                                        5.6603
# 1  1962                                        5.6597
# 2  1963                                        5.7157
# 3  1964                                        5.7468
# 4  1965                                        5.9014

# %%
df3.head(5)
# Out:
#    Year average_rain_fall_mm_per_year
# 0  1985                           327
# 1  1986                           327
# 2  1987                           327
# 3  1989                           327
# 4  1990                           327

# %%
# Merge Columns
new_df = df1.merge(df2, on='Year').merge(df3, on='Year')

# %%
new_df.head(5)
# Out:
# Empty DataFrame
# Columns: [Average_Temparature, Crops - Cassava - 125 - Yield - 5419 - hg/ha, Year, average_rain_fall_mm_per_year]
# Index: []

# %%
new_df.to_csv('new_dataset.csv', index=False)
